# %% [markdown]
# # 最长子序列问题

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 创建类solution
class solution:
    '''
        给定一个词典和一个字符串s,你只能删除s
        里的某些字符。你需要找到在词典里最长
        的可以生成的词，如果有多个，请输出字
        典序最小的一个
        输入：
        word_dict = ["technology","nology","google","coo"]
        s = "chnology"
        输出 ：
        "nology"
    '''
    def isSubsequence(self,word,s):
        if len(word) > len(s):
            return False
        index = 0
        for letter in s:
            if word[index] == letter:
                index += 1
            if index == len(word):
                return True
        return False
    
    
    def longestSequence(self,word_dict,s):
        longest_sequence = ''
        for word in word_dict:
            if self.isSubsequence(word,s):
                if len(word) > len(longest_sequence) or (len(word) == len(longest_sequence) and word < longest_sequencee):
                    longest_sequence = word
        return longest_sequence
    
    
if __name__ == '__main__':
    word_dict = ["technology","nology","google","coo"]
    s = "chnology"
    sol = solution()
    longest_sequence = sol.longestSequence(word_dict,s)
    print(longest_sequence)
# Out:
# nology
